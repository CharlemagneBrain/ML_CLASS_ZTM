# %%
    import pandas as pd

# %%
# 2 principaux types de données

series = pd.Series(["Toyota", "Honda", "BMW"])

# %%
series
# Out:
# 0    Toyota
# 1     Honda
# 2       BMW
# dtype: object

# %%
# serie = unidimensionnelle = une colonne

# %%
couleurs = pd.Series(["rouge", "vert",  "bleu"])
couleurs
# Out:
# 0    rouge
# 1     vert
# 2     bleu
# dtype: object

# %%
# Dataframes = Bidimensionnel = lignes & Colonnes
car_data = pd.DataFrame({
    'car_make' : series,
    'car_color' : couleurs
})

car_data
# Out:
#   car_make car_color
# 0   Toyota     rouge
# 1    Honda      vert
# 2      BMW      bleu

# %%
# On importe nos données now
car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporter notre dataframe
car_sales.to_csv("exported-dataframe-car_sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-dataframe-car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
#  ## Description des données (Data Describing)

# %%
#Attributes

car_sales.dtypes #méta-informations stockées sur les données de vente de voitures
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe() #Ne fonctionne que sur les colonnes numériques
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean() #Analyse Statistique des données
# Out:
# <ipython-input-19-34972e2e0731>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean() #Analyse Statistique des données
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 5000, 2500])
car_prices.mean()
# Out:
# 3500.0

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Affichage et Sélection des données

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc et .iloc
animals = pd.Series(["lion", "jaguar", "cerf", "oiseau", "chien"], index=[0,5,10,15,5])

# %%
animals
# Out:
# 0       lion
# 5     jaguar
# 10      cerf
# 15    oiseau
# 5      chien
# dtype: object

# %%
animals.loc[5]
# Out:
# 5    jaguar
# 5     chien
# dtype: object

# %%
car_sales.loc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
animals
# Out:
# 0       lion
# 5     jaguar
# 10      cerf
# 15    oiseau
# 5      chien
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'oiseau'

# %%
car_sales.iloc[5]
# Out:
# Make                Toyota
# Colour               Green
# Odometer (KM)        99213
# Doors                    4
# Price            $4,500.00
# Name: 5, dtype: object

# %%
animals
# Out:
# 0       lion
# 5     jaguar
# 10      cerf
# 15    oiseau
# 5      chien
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0       lion
# 5     jaguar
# 10      cerf
# dtype: object

# %%
car_sales.loc[:5]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Doors"] == 5]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales["Odometer (KM)"] >= 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# GroupBy
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(["Colour"]).mean()
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()# Histogramme == distibution ==  répartition des données
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipuler mes Données

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales["Make"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  TOYOTA  White         150043      4   4000
# 1   HONDA    Red          87899      4   5000
# 2  TOYOTA   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  NISSAN  White         213095      4   3500
# 5  TOYOTA  Green          99213      4   4500
# 6   HONDA   Blue          45698      4   7500
# 7   HONDA   Blue          54738      4   7000
# 8  TOYOTA  White          60000      4   6250
# 9  NISSAN  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
 car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
 car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing = car_sales_missing_dropped

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing = car_sales_missing_dropped.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
# Création de colonne à partir des Series

seats_column = pd.Series([5,5,5,5])

# On appelle une nouvelle colone

car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  TOYOTA  White         150043      4   4000    5.0
# 1   HONDA    Red          87899      4   5000    5.0
# 2  TOYOTA   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  NISSAN  White         213095      4   3500    NaN
# 5  TOYOTA  Green          99213      4   4500    NaN
# 6   HONDA   Blue          45698      4   7500    NaN
# 7   HONDA   Blue          54738      4   7000    NaN
# 8  TOYOTA  White          60000      4   6250    NaN
# 9  NISSAN  White          31600      4   9700    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  TOYOTA  White         150043      4   4000    5.0
# 1   HONDA    Red          87899      4   5000    5.0
# 2  TOYOTA   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  NISSAN  White         213095      4   3500    5.0
# 5  TOYOTA  Green          99213      4   4500    5.0
# 6   HONDA   Blue          45698      4   7500    5.0
# 7   HONDA   Blue          54738      4   7000    5.0
# 8  TOYOTA  White          60000      4   6250    5.0
# 9  NISSAN  White          31600      4   9700    5.0

# %%
# Création d'une colone à partir d'une liste

fuel = [7.5, 9.2, 5.0, 9.6, 8.7, 7.5, 9.2, 5.0, 9.6, 8.7]

car_sales["Carburant"] = fuel
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7

# %%
#Création d'une colonne à partir d'une autre
car_sales["Carburant Total"] = car_sales["Odometer (KM)"] / 100 * car_sales["Carburant"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7
#
#    Carburant Total
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         7440.975
# 6         4204.216
# 7         2736.900
# 8         5760.000
# 9         2749.200

# %%
#Création d'une colonne à partir d'une seule valeur
car_sales["Nombre de roues"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7
#
#    Carburant Total  Nombre de roues
# 0        11253.225                4
# 1         8086.708                4
# 2         1627.450                4
# 3         1073.184                4
# 4        18539.265                4
# 5         7440.975                4
# ...

# %%
car_sales =  car_sales.drop("Carburant Total", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7
#
#    Nombre de roues
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
#
#    Nombre de roues
# 1                4
# 8                4
# 3                4
# 9                4
# 2                4
# 5                4
# 4                4
# 7                4
# 0                4
# 6                4

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0  TOYOTA  White         150043      4   4000    5.0        7.5
# 1   HONDA    Red          87899      4   5000    5.0        9.2
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 3     BMW  Black          11179      5  22000    5.0        9.6
# 4  NISSAN  White         213095      4   3500    5.0        8.7
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 6   HONDA   Blue          45698      4   7500    5.0        9.2
# 7   HONDA   Blue          54738      4   7000    5.0        5.0
# 8  TOYOTA  White          60000      4   6250    5.0        9.6
# 9  NISSAN  White          31600      4   9700    5.0        8.7
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# 3                4                True
# 4                4                True
# ...

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0      3     BMW  Black          11179      5  22000    5.0        9.6
# 1      8  TOYOTA  White          60000      4   6250    5.0        9.6
# 2      0  TOYOTA  White         150043      4   4000    5.0        7.5
# 3      5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 4      2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 5      7   HONDA   Blue          54738      4   7000    5.0        5.0
# 6      4  NISSAN  White         213095      4   3500    5.0        8.7
# 7      6   HONDA   Blue          45698      4   7500    5.0        9.2
# 8      9  NISSAN  White          31600      4   9700    5.0        8.7
# 9      1   HONDA    Red          87899      4   5000    5.0        9.2
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# ...

# %%
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0      3     BMW  Black          11179      5  22000    5.0        9.6
# 1      8  TOYOTA  White          60000      4   6250    5.0        9.6
# 2      0  TOYOTA  White         150043      4   4000    5.0        7.5
# 3      5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 4      2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 5      7   HONDA   Blue          54738      4   7000    5.0        5.0
# 6      4  NISSAN  White         213095      4   3500    5.0        8.7
# 7      6   HONDA   Blue          45698      4   7500    5.0        9.2
# 8      9  NISSAN  White          31600      4   9700    5.0        8.7
# 9      1   HONDA    Red          87899      4   5000    5.0        9.2
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# ...

# %%
# Entrainement sur 20% des données
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 5  TOYOTA  Green          99213      4   4500    5.0        7.5
#
#    Nombre de roues  Passed road safety
# 2                4                True
# 5                4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0      7   HONDA   Blue          54738      4   7000    5.0        5.0
# 1      6   HONDA   Blue          45698      4   7500    5.0        9.2
# 2      4  NISSAN  White         213095      4   3500    5.0        8.7
# 3      2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 4      9  NISSAN  White          31600      4   9700    5.0        8.7
# 5      1   HONDA    Red          87899      4   5000    5.0        9.2
# 6      8  TOYOTA  White          60000      4   6250    5.0        9.6
# 7      5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 8      3     BMW  Black          11179      5  22000    5.0        9.6
# 9      0  TOYOTA  White         150043      4   4000    5.0        7.5
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# ...

# %%
car_sales.reset_index(drop=True, inplace=True)
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0      3     BMW  Black          11179      5  22000    5.0        9.6
# 1      8  TOYOTA  White          60000      4   6250    5.0        9.6
# 2      0  TOYOTA  White         150043      4   4000    5.0        7.5
# 3      5  TOYOTA  Green          99213      4   4500    5.0        7.5
# 4      2  TOYOTA   Blue          32549      3   7000    5.0        5.0
# 5      7   HONDA   Blue          54738      4   7000    5.0        5.0
# 6      4  NISSAN  White         213095      4   3500    5.0        8.7
# 7      6   HONDA   Blue          45698      4   7500    5.0        9.2
# 8      9  NISSAN  White          31600      4   9700    5.0        8.7
# 9      1   HONDA    Red          87899      4   5000    5.0        9.2
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors  Price  Seats  Carburant  \
# 0      3     BMW  Black       6986.875      5  22000    5.0        9.6
# 1      8  TOYOTA  White      37500.000      4   6250    5.0        9.6
# 2      0  TOYOTA  White      93776.875      4   4000    5.0        7.5
# 3      5  TOYOTA  Green      62008.125      4   4500    5.0        7.5
# 4      2  TOYOTA   Blue      20343.125      3   7000    5.0        5.0
# 5      7   HONDA   Blue      34211.250      4   7000    5.0        5.0
# 6      4  NISSAN  White     133184.375      4   3500    5.0        8.7
# 7      6   HONDA   Blue      28561.250      4   7500    5.0        9.2
# 8      9  NISSAN  White      19750.000      4   9700    5.0        8.7
# 9      1   HONDA    Red      54936.875      4   5000    5.0        9.2
#
#    Nombre de roues  Passed road safety
# 0                4                True
# 1                4                True
# 2                4                True
# ...
